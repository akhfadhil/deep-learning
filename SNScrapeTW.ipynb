# %%
# !pip install snscrape
import snscrape.modules.twitter as sntwitter
import pandas as pd
import re
from textblob import TextBlob
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
query = '(#ruusisdiknas)'

# %%
tweets = []
limit = 0
hasilAnalisis = []

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    if  limit == 1:
        break
    else:
        limit=limit+1
        print(tweet.count)
        # tweet_properties = {}
        # tweet_properties['tanggal_tweet'] = tweet.date
        # tweet_properties['pengguna'] = tweet.username
        # tweet_properties['isi'] = tweet.content
        # tweet_clean = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",tweet.content).split())
        
        # analysis = TextBlob(tweet_clean)
        # an = analysis.translate(from_lang='id', to='en')
        
        # if an.sentiment.polarity > 0.0:
        #   tweet_properties['sentimen'] = 'Positif'
        # elif an.sentiment.polarity == 0.0:
        #   tweet_properties['sentimen'] = 'Netral'
        # else:
        #   tweet_properties['sentimen'] = 'Negatif'

        # if tweet.retweetCount > 0:
        #   if tweet_properties not in hasilAnalisis:
        #     hasilAnalisis.append(tweet_properties)
        # else:
        #   hasilAnalisis.append(tweet_properties)
# Out:
# <built-in method count of Tweet object at 0x7f88502e6710>
